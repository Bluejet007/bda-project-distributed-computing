# %%
import pyspark.sql as ps
import pyspark.sql.functions as F
from pyspark.ml.feature import StringIndexer
import pandas
inp_file_path: str = 'file:///D:/MAHE/5thSem/BDA2/data/2019-Sma.csv'
print(inp_file_path)
# Out:
# file:///D:/MAHE/5thSem/BDA2/data/2019-Oct.csv

# %%
spark: ps.SparkSession = ps.SparkSession.builder.master("yarn").appName("test").getOrCreate()
raw_data: ps.DataFrame = spark.read.csv(inp_file_path, header=True, inferSchema=True)

# %%
raw_data.show(5)
raw_data.summary()
# Out:
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |         event_time|event_type|product_id|        category_id|       category_code|   brand|  price|  user_id|        user_session|
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |2019-10-01 05:30:00|      view|  44600062|2103807459595387724|                null|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|
# |2019-10-01 05:30:00|      view|   3900821|2053013552326770905|appliances.enviro...|    aqua|   33.2|554748717|9333dfbd-b87a-470...|
# |2019-10-01 05:30:01|      view|  17200506|2053013559792632471|furniture.living_...|    null|  543.1|519107250|566511c2-e2e3-422...|
# |2019-10-01 05:30:01|      view|   1307067|2053013558920217191|  computers.notebook|  lenovo| 251.74|550050854|7c90fc70-0e80-459...|
# |2019-10-01 05:30:04|      view|   1004237|2053013555631882655|electronics.smart...|   apple|1081.98|535871217|c6bd7419-2748-4c5...|
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# only showing top 5 rows
# DataFrame[summary: string, event_type: string, product_id: string, category_id: string, category_code: string, brand: string, price: string, user_id: string, user_session: string]

# %%
str_ind = StringIndexer(inputCols=['event_type', 'category_code'], outputCols=['event_ind', 'category_ind'], handleInvalid='keep')
str_ind = str_ind.fit(raw_data)
eve_dict = {label: ind for ind, label in enumerate(str_ind.labelsArray[0])}
cat_dict = {label: ind for ind, label in enumerate(str_ind.labelsArray[1])}

df = str_ind.transform(raw_data)
df = df.drop(df.category_id, df.event_type, df.category_code). \
    withColumnsRenamed({'event_ind': 'event_type', 'category_ind': 'category_code'}). \
    withColumn('event_time', F.to_date(df.event_time))

# %%
print(eve_dict)
print(cat_dict)
df.show()
df.summary()
# Out:
# {'view': 0, 'cart': 1, 'purchase': 2}
# {'electronics.smartphone': 0, 'electronics.clocks': 1, 'computers.notebook': 2, 'electronics.video.tv': 3, 'electronics.audio.headphone': 4, 'appliances.kitchen.refrigerators': 5, 'appliances.kitchen.washer': 6, 'appliances.environment.vacuum': 7, 'apparel.shoes': 8, 'auto.accessories.player': 9, 'computers.desktop': 10, 'apparel.shoes.keds': 11, 'furniture.bedroom.bed': 12, 'electronics.tablet': 13, 'electronics.audio.subwoofer': 14, 'furniture.living_room.cabinet': 15, 'construction.tools.drill': 16, 'electronics.telephone': 17, 'auto.accessories.videoregister': 18, 'kids.carriage': 19, 'furniture.living_room.sofa': 20, 'appliances.kitchen.blender': 21, 'appliances.kitchen.oven': 22, 'auto.accessories.alarm': 23, 'accessories.bag': 24, 'appliances.kitchen.kettle': 25, 'appliances.kitchen.microwave': 26, 'appliances.iron': 27, 'appliances.kitchen.meat_grinder': 28, 'appliances.environment.air_heater': 29, 'appliances.sewing_machine': 30, 'computers.peripherals.printer': 31, 'appliances.environment.water_heater': 32, 'construction.tools.saw': 33, 'apparel.costume': 34, 'sport.bicycle': 35, 'construction.tools.generator': 36, 'kids.toys': 37, 'furniture.kitchen.chair': 38, 'appliances.kitchen.hood': 39, 'appliances.kitchen.hob': 40, 'furniture.kitchen.table': 41, 'computers.peripherals.monitor': 42, 'electronics.audio.acoustic': 43, 'construction.tools.welding': 44, 'appliances.kitchen.mixer': 45, 'kids.skates': 46, 'appliances.kitchen.dishwasher': 47, 'appliances.kitchen.coffee_machine': 48, 'computers.components.videocards': 49, 'appliances.kitchen.grill': 50, 'furniture.living_room.chair': 51, 'computers.peripherals.mouse': 52, 'appliances.personal.hair_cutter': 53, 'appliances.personal.scales': 54, 'computers.components.hdd': 55, 'auto.accessories.compressor': 56, 'apparel.jeans': 57, 'computers.peripherals.keyboard': 58, 'computers.components.cpu': 59, 'appliances.kitchen.juicer': 60, 'kids.dolls': 61, 'apparel.underwear': 62, 'computers.components.cooler': 63, 'accessories.wallet': 64, 'auto.accessories.radar': 65, 'computers.components.motherboard': 66, 'computers.components.memory': 67, 'electronics.camera.video': 68, 'appliances.environment.air_conditioner': 69, 'apparel.dress': 70, 'electronics.audio.music_tools.piano': 71, 'sport.trainer': 72, 'appliances.ironing_board': 73, 'construction.tools.pump': 74, 'kids.swing': 75, 'computers.ebooks': 76, 'electronics.audio.microphone': 77, 'appliances.kitchen.toster': 78, 'construction.components.faucet': 79, 'kids.fmcg.diapers': 80, 'furniture.bedroom.blanket': 81, 'construction.tools.light': 82, 'furniture.bedroom.pillow': 83, 'apparel.tshirt': 84, 'computers.components.power_supply': 85, 'appliances.personal.massager': 86, 'furniture.bathroom.toilet': 87, 'apparel.trousers': 88, 'construction.tools.painting': 89, 'medicine.tools.tonometer': 90, 'furniture.bathroom.bath': 91, 'apparel.shirt': 92, 'appliances.kitchen.steam_cooker': 93, 'apparel.shoes.moccasins': 94, 'electronics.video.projector': 95, 'auto.accessories.parktronic': 96, 'appliances.kitchen.coffee_grinder': 97, 'electronics.camera.photo': 98, 'furniture.universal.light': 99, 'apparel.shoes.sandals': 100, 'auto.accessories.winch': 101, 'stationery.cartrige': 102, 'country_yard.cultivator': 103, 'apparel.shoes.slipons': 104, 'country_yard.lawn_mower': 105, 'computers.peripherals.camera': 106, 'accessories.umbrella': 107, 'sport.snowboard': 108, 'sport.tennis': 109, 'sport.ski': 110, 'apparel.shoes.ballet_shoes': 111, 'apparel.jumper': 112, 'apparel.sock': 113, 'apparel.scarf': 114, 'apparel.belt': 115, 'appliances.environment.fan': 116, 'apparel.shoes.espadrilles': 117, 'apparel.shoes.step_ins': 118, 'country_yard.furniture.hammok': 119, 'apparel.skirt': 120, 'apparel.shorts': 121, 'construction.tools.soldering': 122, 'apparel.jacket': 123, 'auto.accessories.anti_freeze': 124, 'country_yard.furniture.bench': 125}
# +----------+----------+--------+-------+---------+--------------------+----------+-------------+
# |event_time|product_id|   brand|  price|  user_id|        user_session|event_type|category_code|
# +----------+----------+--------+-------+---------+--------------------+----------+-------------+
# |2019-10-01|  44600062|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|       0.0|        126.0|
# |2019-10-01|   3900821|    aqua|   33.2|554748717|9333dfbd-b87a-470...|       0.0|         32.0|
# |2019-10-01|  17200506|    null|  543.1|519107250|566511c2-e2e3-422...|       0.0|         20.0|
# |2019-10-01|   1307067|  lenovo| 251.74|550050854|7c90fc70-0e80-459...|       0.0|          2.0|
# |2019-10-01|   1004237|   apple|1081.98|535871217|c6bd7419-2748-4c5...|       0.0|          0.0|
# |2019-10-01|   1480613|  pulser| 908.62|512742880|0d0d91c2-c9c2-4e8...|       0.0|         10.0|
# |2019-10-01|  17300353|   creed| 380.96|555447699|4fe811e9-91de-46d...|       0.0|        126.0|
# |2019-10-01|  31500053|luminarc|  41.16|550978835|6280d577-25c8-414...|       0.0|        126.0|
# |2019-10-01|  28719074|   baden| 102.71|520571932|ac1cd4e5-a3ce-422...|       0.0|         11.0|
# |2019-10-01|   1004545|  huawei| 566.01|537918940|406c46ed-90a4-478...|       0.0|          0.0|
# |2019-10-01|   2900536|elenberg|  51.46|555158050|b5bdd0b3-4ca2-4c5...|       0.0|         26.0|
# |2019-10-01|   1005011| samsung| 900.64|530282093|50a293fb-5940-41b...|       0.0|          0.0|
# |2019-10-01|   3900746|   haier| 102.38|555444559|98b88fa0-d8fa-4b9...|       0.0|         32.0|
# |2019-10-01|  44600062|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|       0.0|        126.0|
# |2019-10-01|  13500240|     brw|  93.18|555446365|7f0062d8-ead0-4e0...|       0.0|         12.0|
# |2019-10-01|  23100006|    null| 357.79|513642368|17566c27-0a8f-450...|       0.0|        126.0|
# |2019-10-01|   1801995|   haier| 193.03|537192226|e3151795-c355-4ef...|       0.0|          3.0|
# |2019-10-01|  10900029|   bosch|  58.95|519528062|901b9e3c-3f8f-414...|       0.0|         45.0|
# |2019-10-01|   1306631|      hp| 580.89|550050854|7c90fc70-0e80-459...|       0.0|          2.0|
# |2019-10-01|   1005135|   apple|1747.79|535871217|c6bd7419-2748-4c5...|       0.0|          0.0|
# +----------+----------+--------+-------+---------+--------------------+----------+-------------+
# only showing top 20 rows
# DataFrame[summary: string, product_id: string, brand: string, price: string, user_id: string, user_session: string, event_type: string, category_code: string]

# %%
visits = df.groupBy(F.to_date(df.event_time).alias("event_time")). \
    agg(F.countDistinct("user_session").alias("Number_of_daily_visits"),
        F.countDistinct("user_id").alias("Number_of_daily_visitors"))

sales = df.where(df.event_type == eve_dict['purchase']). \
    withColumn("event_time", F.to_date(df.event_time)). \
    groupBy("event_time"). \
    agg(F.count("event_type").alias("number_of_daily_sales"),
        F.sum("price").alias("total_daily_sales"))

daily = visits.join(sales, on=["event_time"], how="left"). \
    withColumn("conversion_rate", F.col('number_of_daily_sales') / F.col('number_of_daily_visits'))
daily.show()

# %%
def extract_category_code(input_text: str):
    return input_text.split('.')

extract_category_udf = F.udf(extract_category_code)

# %%
spark.stop()
